# %% [markdown]
# # 🧩 ข้อตกลง
#   - 🧩 สัญลักษณ์ หัวข้อใหญ่
#   - ❓  สัญลักษณ์ กิจกรรม
#   - 🥇 สัญลักษณ์ ตอบคำถามกิจกรรม

# %% [markdown]
# # ⏩ ข้อมูลที่ต้องการ
# - สาขา 1 : DataDE_USA_BI.csv

# %% [markdown]
# # 🧩 1. เชื่อมต่อ MongoDB

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 21.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.8.0

# %%
import pandas as pd
from pymongo import MongoClient
from pprint import pprint

# %%
uri = "mongodb+srv://lcdrbuncha:SaK46XTH3yuE8j5w@cluster0.3uz0c0m.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)

# %%
# ดูข้อมูลสถานะ ภายหลังเชื่อมต่อสำเร็จ

client.stats
# Out:
# Database(MongoClient(host=['ac-s6abnst-shard-00-00.yuisrie.mongodb.net:27017', 'ac-s6abnst-shard-00-01.yuisrie.mongodb.net:27017', 'ac-s6abnst-shard-00-02.yuisrie.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-7ptjvz-shard-0', tls=True), 'stats')

# %% [markdown]
# # 🧩 2. เลือกฐานข้อมูล

# %%
# แสดงรายการฐานข้อมูล

client.list_database_names()
# Out:
# ['MyDB', 'sample_mflix', 'admin', 'local']

# %%
# ข้อมูล CSV ที่ได้จาก ETL

usa_bi = pd.read_csv('/content/DataDE_USA_BI.csv')
usa_bi
# Out:
#     Customer.ID    Customer.Name Market  Zip.code Order.Date        Order.ID  \
# 0     CC-126704   Craig Carreira     US   76248.0    00:00.0  CA-2013-167759
# 1     RD-199004      Ruben Dartt     US   76234.0    00:00.0  CA-2013-154235
# 2     PF-191654       Philip Fox     US   77406.0    00:00.0  US-2011-134614
# 3     LT-171104     Liz Thompson     US   77407.0    00:00.0  US-2012-104430
# 4     MC-181004    Mick Crebagga     US   77095.0    00:00.0  US-2012-129637
# ..          ...              ...    ...       ...        ...             ...
# 495   MY-182954  Muhammed Yedwab     US   75048.0    00:00.0  CA-2014-167626
# 496   DB-130604      Dave Brooks     US   77584.0    00:00.0  CA-2014-132353
# 497   LC-168704    Lena Cacioppo     US   79830.0    00:00.0  US-2014-125647
# 498   MA-175604     Matt Abelman     US   76706.0    00:00.0  CA-2014-110373
# 499   CY-127454     Craig Yedwab     US   75082.0    00:00.0  CA-2014-117114
#
#     Order.Priority       Product.ID  \
# 0             High  TEC-PH-10003171
# 1             High  FUR-FU-10004006
# 2           Medium  FUR-TA-10004534
# 3             High  OFF-BI-10000301
# 4           Medium  FUR-FU-10000965
# ..             ...              ...
# 495         Medium  TEC-AC-10004353
# 496         Medium  TEC-PH-10004536
# 497         Medium  TEC-PH-10004188
# 498         Medium  TEC-PH-10001536
# 499         Medium  TEC-PH-10004042
#
#                                           Product.Name  SalePrice  Quantity  \
# 0      Plantronics Encore H101 Dual Earpiecesย Headset      20.68         3
# 1    Deflect-o DuraMat Lighweight, Studded, Beveled...      20.39         3
# 2                      Bevis 44 x 96 Conference Tables      34.53         6
# 3                               GBC Instant Report Kit      12.58         4
# 4    Howard Miller 11-1/2" Diameter Ridgewood Wall ...      14.01         2
# ..                                                 ...        ...       ...
# 495                              Hypercom P1300 Pinpad      15.68         2
# 496                           Avaya 5420 Digital phone      66.02         3
# 497  OtterBox Commuter Series Case - Samsung Galaxy S4      14.88         2
# 498               Spigen Samsung Galaxy S5 Case Wallet      13.33         2
# 499  ClearOne Communications CHAT 70 OCย Speaker Phone      47.39         4
#
#     Ship.Date  Shipping.Cost
# 0     00:00.0           8.68
# 1     00:00.0           8.39
# 2     00:00.0          22.53
# 3     00:00.0           0.58
# 4     00:00.0           2.01
# ..        ...            ...
# 495   00:00.0           3.68
# 496   00:00.0          54.02
# 497   00:00.0           2.88
# 498   00:00.0           1.33
# 499   00:00.0          35.39
#
# [500 rows x 13 columns]

# %%
dic_bi = usa_bi.to_dict(orient= "records")

# %%
dic_bi
# Out:
# [{'Customer.ID': 'CC-126704',
#   'Customer.Name': 'Craig Carreira',
#   'Market': 'US',
#   'Zip.code': 76248.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-167759',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10003171',
#   'Product.Name': 'Plantronics Encore H101 Dual Earpiecesย\xa0Headset',
#   'SalePrice': 20.68,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.68},
#  {'Customer.ID': 'RD-199004',
#   'Customer.Name': 'Ruben Dartt',
#   'Market': 'US',
#   'Zip.code': 76234.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-154235',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-FU-10004006',
#   'Product.Name': 'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low Pile Carpeting',
#   'SalePrice': 20.39,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.39},
#  {'Customer.ID': 'PF-191654',
#   'Customer.Name': 'Philip Fox',
#   'Market': 'US',
#   'Zip.code': 77406.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-134614',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-TA-10004534',
#   'Product.Name': 'Bevis 44 x 96 Conference Tables',
#   'SalePrice': 34.53,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 22.53},
#  {'Customer.ID': 'LT-171104',
#   'Customer.Name': 'Liz Thompson',
#   'Market': 'US',
#   'Zip.code': 77407.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-104430',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-BI-10000301',
#   'Product.Name': 'GBC Instant Report Kit',
#   'SalePrice': 12.58,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.58},
#  {'Customer.ID': 'MC-181004',
#   'Customer.Name': 'Mick Crebagga',
#   'Market': 'US',
#   'Zip.code': 77095.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-129637',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10000965',
#   'Product.Name': 'Howard Miller 11-1/2" Diameter Ridgewood Wall Clock',
#   'SalePrice': 14.01,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.01},
#  {'Customer.ID': 'TB-212504',
#   'Customer.Name': 'Tim Brockman',
#   'Market': 'US',
#   'Zip.code': 77327.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-117898',
#   'Order.Priority': 'Low',
#   'Product.ID': 'OFF-EN-10004459',
#   'Product.Name': 'Security-Tint Envelopes',
#   'SalePrice': 14.23,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.23},
#  {'Customer.ID': 'MC-181004',
#   'Customer.Name': 'Mick Crebagga',
#   'Market': 'US',
#   'Zip.code': 75034.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-129637',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AR-10003829',
#   'Product.Name': 'Newell 35',
#   'SalePrice': 13.15,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.15},
#  {'Customer.ID': 'MC-181004',
#   'Customer.Name': 'Mick Crebagga',
#   'Market': 'US',
#   'Zip.code': 76063.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-129637',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10003716',
#   'Product.Name': 'Tennsco Double-Tier Lockers',
#   'SalePrice': 20.98,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.98},
#  {'Customer.ID': 'AB-101054',
#   'Customer.Name': 'Adrian Barton',
#   'Market': 'US',
#   'Zip.code': 77642.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-140781',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-AC-10000682',
#   'Product.Name': 'Kensington K72356US Mouse-in-a-Box USB Desktop Mouse',
#   'SalePrice': 17.7,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.7},
#  {'Customer.ID': 'GG-146504',
#   'Customer.Name': 'Greg Guthrie',
#   'Market': 'US',
#   'Zip.code': 75115.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-145597',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AR-10001958',
#   'Product.Name': 'Stanley Bostitch Contemporary Electric Pencil Sharpeners',
#   'SalePrice': 25.06,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 13.06},
#  {'Customer.ID': 'VM-218354',
#   'Customer.Name': 'Vivian Mathis',
#   'Market': 'US',
#   'Zip.code': 77573.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-133872',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10002082',
#   'Product.Name': 'GBC Twin Loop Wire Binding Elements',
#   'SalePrice': 16.63,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 4.63},
#  {'Customer.ID': 'MS-173654',
#   'Customer.Name': 'Maribeth Schnelling',
#   'Market': 'US',
#   'Zip.code': 76063.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-127488',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-LA-10001613',
#   'Product.Name': 'Avery File Folder Labels',
#   'SalePrice': 13.19,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.19},
#  {'Customer.ID': 'VM-218354',
#   'Customer.Name': 'Vivian Mathis',
#   'Market': 'US',
#   'Zip.code': 75232.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-133872',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10000521',
#   'Product.Name': 'Verbatim Slim CD and DVD Storage Cases, 50/Pack',
#   'SalePrice': 12.73,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.73},
#  {'Customer.ID': 'HK-148904',
#   'Customer.Name': 'Heather Kirkland',
#   'Market': 'US',
#   'Zip.code': 77372.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-150875',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-TA-10000577',
#   'Product.Name': 'Bretford CR4500 Series Slim Rectangular Table',
#   'SalePrice': 97.22,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 85.22},
#  {'Customer.ID': 'SC-203804',
#   'Customer.Name': 'Shahid Collister',
#   'Market': 'US',
#   'Zip.code': 78212.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-142293',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-AC-10001109',
#   'Product.Name': 'Logitech Trackman Marble Mouse',
#   'SalePrice': 33.5,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 21.5},
#  {'Customer.ID': 'NS-186404',
#   'Customer.Name': 'Noel Staavos',
#   'Market': 'US',
#   'Zip.code': 78003.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-163895',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-BI-10004970',
#   'Product.Name': 'ACCOHIDE 3-Ring Binder, Blue, 1"',
#   'SalePrice': 12.34,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.34},
#  {'Customer.ID': 'HK-148904',
#   'Customer.Name': 'Heather Kirkland',
#   'Market': 'US',
#   'Zip.code': 75019.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-150875',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001254',
#   'Product.Name': 'Jabra BIZ 2300 Duo QD Duo Cordedย\xa0Headset',
#   'SalePrice': 19.38,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 7.38},
#  {'Customer.ID': 'TC-214754',
#   'Customer.Name': 'Tony Chapman',
#   'Market': 'US',
#   'Zip.code': 77040.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-112200',
#   'Order.Priority': 'Low',
#   'Product.ID': 'OFF-BI-10002571',
#   'Product.Name': 'Avery Framed View Binder, EZD Ring (Locking), Navy, 1 1/2"',
#   'SalePrice': 13.48,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.48},
#  {'Customer.ID': 'TD-209954',
#   'Customer.Name': 'Tamara Dahlen',
#   'Market': 'US',
#   'Zip.code': 77979.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-114468',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AP-10000696',
#   'Product.Name': 'Holmes Odor Grabber',
#   'SalePrice': 12.83,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.83},
#  {'Customer.ID': 'TD-209954',
#   'Customer.Name': 'Tamara Dahlen',
#   'Market': 'US',
#   'Zip.code': 77056.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-114468',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-FA-10003021',
#   'Product.Name': 'Staples',
#   'SalePrice': 14.6,
#   'Quantity': 8,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.6},
#  {'Customer.ID': 'TD-209954',
#   'Customer.Name': 'Tamara Dahlen',
#   'Market': 'US',
#   'Zip.code': 78750.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-114468',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-PA-10000809',
#   'Product.Name': 'Xerox 206',
#   'SalePrice': 13.13,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.13},
#  {'Customer.ID': 'TD-209954',
#   'Customer.Name': 'Tamara Dahlen',
#   'Market': 'US',
#   'Zip.code': 77027.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-114468',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-SU-10004231',
#   'Product.Name': 'Acme Tagit Stainless Steel Antibacterial Scissors',
#   'SalePrice': 15.12,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.12},
#  {'Customer.ID': 'FM-143804',
#   'Customer.Name': 'Fred McMath',
#   'Market': 'US',
#   'Zip.code': 78410.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-134796',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10003505',
#   'Product.Name': 'Geemarc AmpliPOWER60',
#   'SalePrice': 23.7,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 11.7},
#  {'Customer.ID': 'CS-122504',
#   'Customer.Name': 'Chris Selesnick',
#   'Market': 'US',
#   'Zip.code': 77484.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162775',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-BI-10004187',
#   'Product.Name': 'Staples',
#   'SalePrice': 12.85,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.85},
#  {'Customer.ID': 'CS-122504',
#   'Customer.Name': 'Chris Selesnick',
#   'Market': 'US',
#   'Zip.code': 77338.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162775',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-EN-10001532',
#   'Product.Name': 'Brown Kraft Recycled Envelopes',
#   'SalePrice': 24.66,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 12.66},
#  {'Customer.ID': 'CS-122504',
#   'Customer.Name': 'Chris Selesnick',
#   'Market': 'US',
#   'Zip.code': 78501.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162775',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-EN-10001990',
#   'Product.Name': 'Staples',
#   'SalePrice': 14.88,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.88},
#  {'Customer.ID': 'CS-122504',
#   'Customer.Name': 'Chris Selesnick',
#   'Market': 'US',
#   'Zip.code': 78504.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162775',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-ST-10000025',
#   'Product.Name': 'Fellowes Stor/Drawer Steel Plus Storage Drawers',
#   'SalePrice': 158.29,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 146.29},
#  {'Customer.ID': 'CS-122504',
#   'Customer.Name': 'Chris Selesnick',
#   'Market': 'US',
#   'Zip.code': 78504.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162775',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-AC-10003174',
#   'Product.Name': 'Plantronics S12 Corded Telephone Headset System',
#   'SalePrice': 153.35,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 141.35},
#  {'Customer.ID': 'NB-185804',
#   'Customer.Name': 'Nicole Brennan',
#   'Market': 'US',
#   'Zip.code': 78945.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-151967',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10000193',
#   'Product.Name': 'Tenex Chairmats For Use with Hard Floors',
#   'SalePrice': 23.12,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 11.12},
#  {'Customer.ID': 'KH-163304',
#   'Customer.Name': 'Katharine Harms',
#   'Market': 'US',
#   'Zip.code': 77356.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-157763',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-CH-10000988',
#   'Product.Name': 'Hon Olson Stacker Stools',
#   'SalePrice': 24.72,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 12.72},
#  {'Customer.ID': 'BD-116354',
#   'Customer.Name': 'Brian Derr',
#   'Market': 'US',
#   'Zip.code': 77346.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-109589',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-AC-10003116',
#   'Product.Name': 'Memorex Froggy Flash Drive 8 GB',
#   'SalePrice': 31.15,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 19.15},
#  {'Customer.ID': 'MS-177104',
#   'Customer.Name': 'Maurice Satty',
#   'Market': 'US',
#   'Zip.code': 77477.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-123939',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10000923',
#   'Product.Name': 'Belkin SportFit Armband For iPhone 5s/5c, Fuchsia',
#   'SalePrice': 14.86,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.86},
#  {'Customer.ID': 'BS-113804',
#   'Customer.Name': 'Bill Stewart',
#   'Market': 'US',
#   'Zip.code': 75217.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-160633',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-CO-10002095',
#   'Product.Name': 'Hewlett Packard 610 Color Digital Copier / Printer',
#   'SalePrice': 101.3,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 89.3},
#  {'Customer.ID': 'NM-185204',
#   'Customer.Name': 'Neoma Murray',
#   'Market': 'US',
#   'Zip.code': 75039.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-136049',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10001267',
#   'Product.Name': 'Universal Recycled Hanging Pressboard Report Binders, Letter Size',
#   'SalePrice': 12.45,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.45},
#  {'Customer.ID': 'NP-187004',
#   'Customer.Name': 'Nora Preis',
#   'Market': 'US',
#   'Zip.code': 77434.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-106572',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10000585',
#   'Product.Name': 'Economy Rollaway Files',
#   'SalePrice': 31.39,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 19.39},
#  {'Customer.ID': 'MS-177104',
#   'Customer.Name': 'Maurice Satty',
#   'Market': 'US',
#   'Zip.code': 77450.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-123939',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-LA-10003190',
#   'Product.Name': 'Avery 474',
#   'SalePrice': 12.91,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.91},
#  {'Customer.ID': 'MS-177104',
#   'Customer.Name': 'Maurice Satty',
#   'Market': 'US',
#   'Zip.code': 77532.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-123939',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-ST-10003208',
#   'Product.Name': 'Adjustable Depth Letter/Legal Cart',
#   'SalePrice': 69.95,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 57.95},
#  {'Customer.ID': 'BS-113804',
#   'Customer.Name': 'Bill Stewart',
#   'Market': 'US',
#   'Zip.code': 75087.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-160633',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AR-10004022',
#   'Product.Name': 'Panasonic KP-380BK Classic Electric Pencil Sharpener',
#   'SalePrice': 22.23,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 10.23},
#  {'Customer.ID': 'BS-113804',
#   'Customer.Name': 'Bill Stewart',
#   'Market': 'US',
#   'Zip.code': 76950.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-160633',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10002335',
#   'Product.Name': 'Logitech Media Keyboard K200',
#   'SalePrice': 18.15,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.15},
#  {'Customer.ID': 'PG-188204',
#   'Customer.Name': 'Patrick Gardner',
#   'Market': 'US',
#   'Zip.code': 75211.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-144344',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10003719',
#   'Product.Name': 'Large Capacity Hanging Post Binders',
#   'SalePrice': 16.02,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 4.02},
#  {'Customer.ID': 'PG-188204',
#   'Customer.Name': 'Patrick Gardner',
#   'Market': 'US',
#   'Zip.code': 75219.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-144344',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10000076',
#   'Product.Name': '24-Hour Round Wall Clock',
#   'SalePrice': 20.02,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.02},
#  {'Customer.ID': 'PG-188204',
#   'Customer.Name': 'Patrick Gardner',
#   'Market': 'US',
#   'Zip.code': 76248.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-144344',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10003268',
#   'Product.Name': 'Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#   'SalePrice': 24.49,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 12.49},
#  {'Customer.ID': 'PG-188204',
#   'Customer.Name': 'Patrick Gardner',
#   'Market': 'US',
#   'Zip.code': 76021.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-144344',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10003553',
#   'Product.Name': 'Howard Miller 13-1/2" Diameter Rosebrook Wall Clock',
#   'SalePrice': 26.95,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 14.95},
#  {'Customer.ID': 'DO-136454',
#   'Customer.Name': "Doug O'Connell",
#   'Market': 'US',
#   'Zip.code': 75244.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-117450',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-CH-10003817',
#   'Product.Name': 'Global Value Steno Chair, Gray',
#   'SalePrice': 18.73,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.73},
#  {'Customer.ID': 'BW-112004',
#   'Customer.Name': 'Ben Wallace',
#   'Market': 'US',
#   'Zip.code': 78006.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-167633',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-PA-10004888',
#   'Product.Name': 'Xerox 217',
#   'SalePrice': 12.7,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.7},
#  {'Customer.ID': 'AS-106304',
#   'Customer.Name': 'Ann Steele',
#   'Market': 'US',
#   'Zip.code': 78945.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-124597',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AR-10002280',
#   'Product.Name': 'Staples',
#   'SalePrice': 12.72,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.72},
#  {'Customer.ID': 'AS-106304',
#   'Customer.Name': 'Ann Steele',
#   'Market': 'US',
#   'Zip.code': 77459.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-124597',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-LA-10003190',
#   'Product.Name': 'Avery 474',
#   'SalePrice': 12.28,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.28},
#  {'Customer.ID': 'AS-106304',
#   'Customer.Name': 'Ann Steele',
#   'Market': 'US',
#   'Zip.code': 77027.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-124597',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-LA-10001569',
#   'Product.Name': 'Avery 499',
#   'SalePrice': 12.71,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.71},
#  {'Customer.ID': 'DO-136454',
#   'Customer.Name': "Doug O'Connell",
#   'Market': 'US',
#   'Zip.code': 77598.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-117450',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-PA-10000289',
#   'Product.Name': 'Xerox 213',
#   'SalePrice': 12.63,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.63},
#  {'Customer.ID': 'CW-119054',
#   'Customer.Name': 'Carl Weiss',
#   'Market': 'US',
#   'Zip.code': 78130.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-119214',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-LA-10003077',
#   'Product.Name': 'Avery 500',
#   'SalePrice': 12.37,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.37},
#  {'Customer.ID': 'CW-119054',
#   'Customer.Name': 'Carl Weiss',
#   'Market': 'US',
#   'Zip.code': 76179.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-119214',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-PA-10002893',
#   'Product.Name': 'Wirebound Service Call Books, 5 1/2" x 4"',
#   'SalePrice': 14.74,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.74},
#  {'Customer.ID': 'LW-168254',
#   'Customer.Name': 'Laurel Workman',
#   'Market': 'US',
#   'Zip.code': 77433.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-164721',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AP-10000240',
#   'Product.Name': 'Belkin F9G930V10-GRY 9 Outlet Surge',
#   'SalePrice': 53.8,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 41.8},
#  {'Customer.ID': 'AI-108554',
#   'Customer.Name': 'Arianne Irving',
#   'Market': 'US',
#   'Zip.code': 77340.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-102330',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-LA-10003923',
#   'Product.Name': 'Alphabetical Labels for Top Tab Filing',
#   'SalePrice': 19.9,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 7.9},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 77098.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AP-10001058',
#   'Product.Name': 'Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators',
#   'SalePrice': 185.07,
#   'Quantity': 9,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 173.07},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 75204.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-EN-10003134',
#   'Product.Name': 'Staples',
#   'SalePrice': 14.13,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.13},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 78132.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10001496',
#   'Product.Name': 'Standard Rollaway File with Lock',
#   'SalePrice': 45.69,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 33.69},
#  {'Customer.ID': 'BN-114704',
#   'Customer.Name': 'Brad Norvell',
#   'Market': 'US',
#   'Zip.code': 75093.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-149006',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-ST-10003221',
#   'Product.Name': 'Staples',
#   'SalePrice': 14.12,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.12},
#  {'Customer.ID': 'LW-168254',
#   'Customer.Name': 'Laurel Workman',
#   'Market': 'US',
#   'Zip.code': 75701.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-164721',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-PA-10000575',
#   'Product.Name': 'Wirebound Message Books, Four 2 3/4 x 5 White Forms per Page',
#   'SalePrice': 14.96,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.96},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 75232.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-PA-10003893',
#   'Product.Name': 'Xerox 1962',
#   'SalePrice': 13.11,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.11},
#  {'Customer.ID': 'AH-102104',
#   'Customer.Name': 'Alan Hwang',
#   'Market': 'US',
#   'Zip.code': 79102.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-155040',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10004469',
#   'Product.Name': 'Microsoft Sculpt Comfort Mouse',
#   'SalePrice': 17.46,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.46},
#  {'Customer.ID': 'DB-132704',
#   'Customer.Name': 'Deborah Brumfield',
#   'Market': 'US',
#   'Zip.code': 77429.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-122504',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10003289',
#   'Product.Name': 'Anker Ultra-Slim Mini Bluetooth 3.0 Wireless Keyboard',
#   'SalePrice': 14.82,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.82},
#  {'Customer.ID': 'LW-168254',
#   'Customer.Name': 'Laurel Workman',
#   'Market': 'US',
#   'Zip.code': 78028.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-164721',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-FU-10001940',
#   'Product.Name': 'Staples',
#   'SalePrice': 12.94,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.94},
#  {'Customer.ID': 'AI-108554',
#   'Customer.Name': 'Arianne Irving',
#   'Market': 'US',
#   'Zip.code': 77095.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-102330',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001051',
#   'Product.Name': 'HTC One',
#   'SalePrice': 36.01,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 24.01},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 78061.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002564',
#   'Product.Name': 'OtterBox Defender Series Case - Samsung Galaxy S4',
#   'SalePrice': 17.04,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.04},
#  {'Customer.ID': 'DB-132704',
#   'Customer.Name': 'Deborah Brumfield',
#   'Market': 'US',
#   'Zip.code': 76904.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-122504',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002468',
#   'Product.Name': 'Plantronics CS 50-USB -ย\xa0headsetย\xa0- Convertible, Monaural',
#   'SalePrice': 83.07,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 71.07},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 77301.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10004230',
#   'Product.Name': 'GBC Recycled Grain Textured Covers',
#   'SalePrice': 34.01,
#   'Quantity': 8,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 22.01},
#  {'Customer.ID': 'RW-195404',
#   'Customer.Name': 'Rick Wilson',
#   'Market': 'US',
#   'Zip.code': 79701.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-166093',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10000174',
#   'Product.Name': 'Wilson Jones Clip & Carry Folder Binder Tool for Ring Binders, Clear',
#   'SalePrice': 12.33,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.33},
#  {'Customer.ID': 'JM-156554',
#   'Customer.Name': 'Jim Mitchum',
#   'Market': 'US',
#   'Zip.code': 79821.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112389',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AP-10001626',
#   'Product.Name': 'Commercial WindTunnel Clean Air Upright Vacuum, Replacement Belts, Filtration Bags',
#   'SalePrice': 12.6,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.6},
#  {'Customer.ID': 'JM-156554',
#   'Customer.Name': 'Jim Mitchum',
#   'Market': 'US',
#   'Zip.code': 79416.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112389',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10000419',
#   'Product.Name': 'Rogers Jumbo File, Granite',
#   'SalePrice': 14.47,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.47},
#  {'Customer.ID': 'CA-123104',
#   'Customer.Name': 'Christine Abelman',
#   'Market': 'US',
#   'Zip.code': 75205.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-150434',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10002160',
#   'Product.Name': 'Acco Hanging Data Binders',
#   'SalePrice': 12.28,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.28},
#  {'Customer.ID': 'CA-123104',
#   'Customer.Name': 'Christine Abelman',
#   'Market': 'US',
#   'Zip.code': 75482.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-150434',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10003694',
#   'Product.Name': 'Avery 3 1/2" Diskette Storage Pages, 10/Pack',
#   'SalePrice': 13.12,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.12},
#  {'Customer.ID': 'AT-107354',
#   'Customer.Name': 'Annie Thurman',
#   'Market': 'US',
#   'Zip.code': 79424.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-146500',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10002432',
#   'Product.Name': 'Wilson Jones Standard D-Ring Binders',
#   'SalePrice': 14.01,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.01},
#  {'Customer.ID': 'AT-107354',
#   'Customer.Name': 'Annie Thurman',
#   'Market': 'US',
#   'Zip.code': 77083.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-146500',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10000563',
#   'Product.Name': 'Fellowes Bankers Box Stor/Drawer Steel Plus',
#   'SalePrice': 20.54,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.54},
#  {'Customer.ID': 'JB-154004',
#   'Customer.Name': 'Jennifer Braxton',
#   'Market': 'US',
#   'Zip.code': 77080.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-121608',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AP-10002311',
#   'Product.Name': 'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#   'SalePrice': 35.1,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 23.1},
#  {'Customer.ID': 'CA-123104',
#   'Customer.Name': 'Christine Abelman',
#   'Market': 'US',
#   'Zip.code': 77077.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-150434',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10000895',
#   'Product.Name': 'Polycom VVX 310 VoIP phone',
#   'SalePrice': 43.02,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 31.02},
#  {'Customer.ID': 'JB-154004',
#   'Customer.Name': 'Jennifer Braxton',
#   'Market': 'US',
#   'Zip.code': 76901.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-121608',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10004959',
#   'Product.Name': 'Classic Ivory Antiqueย\xa0Telephoneย\xa0ZL1810',
#   'SalePrice': 28.83,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 16.83},
#  {'Customer.ID': 'CA-123104',
#   'Customer.Name': 'Christine Abelman',
#   'Market': 'US',
#   'Zip.code': 78332.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-150434',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-TA-10004152',
#   'Product.Name': 'Barricks 18" x 48" Non-Folding Utility Table with Bottom Storage Shelf',
#   'SalePrice': 18.33,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.33},
#  {'Customer.ID': 'GG-146504',
#   'Customer.Name': 'Greg Guthrie',
#   'Market': 'US',
#   'Zip.code': 77354.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-136476',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10003650',
#   'Product.Name': 'GBC DocuBind 300 Electric Binding Machine',
#   'SalePrice': 20.81,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.81},
#  {'Customer.ID': 'MP-179654',
#   'Customer.Name': 'Michael Paige',
#   'Market': 'US',
#   'Zip.code': 78666.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-139689',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10004781',
#   'Product.Name': 'GBC Wire Binding Strips',
#   'SalePrice': 13.17,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.17},
#  {'Customer.ID': 'MP-179654',
#   'Customer.Name': 'Michael Paige',
#   'Market': 'US',
#   'Zip.code': 77469.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-139689',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10000145',
#   'Product.Name': 'Zipper Ring Binder Pockets',
#   'SalePrice': 12.24,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.24},
#  {'Customer.ID': 'CG-120404',
#   'Customer.Name': 'Catherine Glotzbach',
#   'Market': 'US',
#   'Zip.code': 78580.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-164350',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-AR-10000538',
#   'Product.Name': 'Boston Model 1800 Electric Pencil Sharpener, Gray',
#   'SalePrice': 21.67,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 9.67},
#  {'Customer.ID': 'KE-164204',
#   'Customer.Name': 'Katrina Edelman',
#   'Market': 'US',
#   'Zip.code': 75601.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-109162',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-CH-10002647',
#   'Product.Name': 'Situations Contoured Folding Chairs, 4/Set',
#   'SalePrice': 25.11,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 13.11},
#  {'Customer.ID': 'BO-113504',
#   'Customer.Name': 'Bill Overfelt',
#   'Market': 'US',
#   'Zip.code': 77057.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-105207',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10004364',
#   'Product.Name': 'Storex Dura Pro Binders',
#   'SalePrice': 13.04,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.04},
#  {'Customer.ID': 'BP-112304',
#   'Customer.Name': 'Benjamin Patterson',
#   'Market': 'US',
#   'Zip.code': 78214.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-141551',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10001249',
#   'Product.Name': 'Avery Heavy-Duty EZD View Binder with Locking Rings',
#   'SalePrice': 12.4,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.4},
#  {'Customer.ID': 'BP-112304',
#   'Customer.Name': 'Benjamin Patterson',
#   'Market': 'US',
#   'Zip.code': 78501.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-141551',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-PA-10001569',
#   'Product.Name': 'Xerox 232',
#   'SalePrice': 12.62,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.62},
#  {'Customer.ID': 'SC-206804',
#   'Customer.Name': 'Steve Carroll',
#   'Market': 'US',
#   'Zip.code': 75703.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-164308',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004120',
#   'Product.Name': 'AT&T 1080 Phone',
#   'SalePrice': 137.04,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 125.04},
#  {'Customer.ID': 'BO-113504',
#   'Customer.Name': 'Bill Overfelt',
#   'Market': 'US',
#   'Zip.code': 77469.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-105207',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-TA-10000617',
#   'Product.Name': 'Hon Practical Foundations 30 x 60 Training Table, Light Gray/Charcoal',
#   'SalePrice': 74.7,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 62.7},
#  {'Customer.ID': 'JE-157154',
#   'Customer.Name': 'Joe Elijah',
#   'Market': 'US',
#   'Zip.code': 75783.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112109',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-BI-10002082',
#   'Product.Name': 'GBC Twin Loop Wire Binding Elements',
#   'SalePrice': 14.2,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.2},
#  {'Customer.ID': 'JE-157154',
#   'Customer.Name': 'Joe Elijah',
#   'Market': 'US',
#   'Zip.code': 77058.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112109',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-BI-10001634',
#   'Product.Name': 'Wilson Jones Active Use Binders',
#   'SalePrice': 12.84,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.84},
#  {'Customer.ID': 'JE-157154',
#   'Customer.Name': 'Joe Elijah',
#   'Market': 'US',
#   'Zip.code': 75041.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112109',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-CH-10004287',
#   'Product.Name': 'SAFCO Arco Folding Chair',
#   'SalePrice': 58.88,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 46.88},
#  {'Customer.ID': 'JE-157154',
#   'Customer.Name': 'Joe Elijah',
#   'Market': 'US',
#   'Zip.code': 77061.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-112109',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-ST-10001505',
#   'Product.Name': 'Perma STOR-ALL Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H',
#   'SalePrice': 15.92,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.92},
#  {'Customer.ID': 'SM-209504',
#   'Customer.Name': 'Suzanne McNair',
#   'Market': 'US',
#   'Zip.code': 77070.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-125724',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10000246',
#   'Product.Name': 'Aluminum Document Frame',
#   'SalePrice': 15.15,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.15},
#  {'Customer.ID': 'MP-174704',
#   'Customer.Name': 'Mark Packer',
#   'Market': 'US',
#   'Zip.code': 76105.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162089',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'FUR-CH-10002304',
#   'Product.Name': 'Global Stack Chair without Arms, Black',
#   'SalePrice': 65.64,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 53.64},
#  {'Customer.ID': 'JB-160004',
#   'Customer.Name': 'Joy Bell-',
#   'Market': 'US',
#   'Zip.code': 78602.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-124674',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-BO-10002202',
#   'Product.Name': 'Atlantic Metals Mobile 2-Shelf Bookcases, Custom Colors',
#   'SalePrice': 41.64,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 29.64},
#  {'Customer.ID': 'MP-174704',
#   'Customer.Name': 'Mark Packer',
#   'Market': 'US',
#   'Zip.code': 76001.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162089',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'OFF-EN-10002230',
#   'Product.Name': 'Airmail Envelopes',
#   'SalePrice': 57.52,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 45.52},
#  {'Customer.ID': 'MP-174704',
#   'Customer.Name': 'Mark Packer',
#   'Market': 'US',
#   'Zip.code': 76904.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-162089',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-PH-10001819',
#   'Product.Name': 'Innergie mMini Combo Duo USB Travel Charging Kit',
#   'SalePrice': 106.8,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 94.8},
#  {'Customer.ID': 'VP-217604',
#   'Customer.Name': 'Victoria Pisteka',
#   'Market': 'US',
#   'Zip.code': 75204.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-109932',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-PA-10001804',
#   'Product.Name': 'Xerox 195',
#   'SalePrice': 13.07,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.07},
#  {'Customer.ID': 'VP-217604',
#   'Customer.Name': 'Victoria Pisteka',
#   'Market': 'US',
#   'Zip.code': 77630.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-109932',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-ST-10000036',
#   'Product.Name': 'Recycled Data-Pak for Archival Bound Computer Printouts, 12-1/2 x 12-1/2 x 16',
#   'SalePrice': 12.22,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.22},
#  {'Customer.ID': 'CM-121604',
#   'Customer.Name': 'Charles McCrossin',
#   'Market': 'US',
#   'Zip.code': 77065.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-139955',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-SU-10001935',
#   'Product.Name': 'Staples',
#   'SalePrice': 12.21,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.21},
#  {'Customer.ID': 'MY-182954',
#   'Customer.Name': 'Muhammed Yedwab',
#   'Market': 'US',
#   'Zip.code': 77095.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-149272',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-CH-10000863',
#   'Product.Name': 'Novimex Swivel Fabric Task Chair',
#   'SalePrice': 49.7,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 37.7},
#  {'Customer.ID': 'MY-182954',
#   'Customer.Name': 'Muhammed Yedwab',
#   'Market': 'US',
#   'Zip.code': 77360.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-149272',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-BI-10004233',
#   'Product.Name': 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#   'SalePrice': 14.77,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.77},
#  {'Customer.ID': 'FM-142904',
#   'Customer.Name': 'Frank Merwin',
#   'Market': 'US',
#   'Zip.code': 78213.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-121160',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10001308',
#   'Product.Name': "GBC Standard Plastic Binding Systems' Combs",
#   'SalePrice': 13.12,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.12},
#  {'Customer.ID': 'FM-142904',
#   'Customer.Name': 'Frank Merwin',
#   'Market': 'US',
#   'Zip.code': 77098.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-121160',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10003094',
#   'Product.Name': 'Self-Adhesive Ring Binder Labels',
#   'SalePrice': 12.08,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.08},
#  {'Customer.ID': 'FM-142904',
#   'Customer.Name': 'Frank Merwin',
#   'Market': 'US',
#   'Zip.code': 76504.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-121160',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10004040',
#   'Product.Name': 'Wilson Jones Impact Binders',
#   'SalePrice': 12.79,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.79},
#  {'Customer.ID': 'FM-142904',
#   'Customer.Name': 'Frank Merwin',
#   'Market': 'US',
#   'Zip.code': 78624.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-121160',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10002485',
#   'Product.Name': 'Rogers Deluxe File Chest',
#   'SalePrice': 17.38,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.38},
#  {'Customer.ID': 'KT-164804',
#   'Customer.Name': 'Kean Thornton',
#   'Market': 'US',
#   'Zip.code': 78015.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-132570',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AR-10000369',
#   'Product.Name': 'Design Ebony Sketching Pencil',
#   'SalePrice': 12.34,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.34},
#  {'Customer.ID': 'KT-164804',
#   'Customer.Name': 'Kean Thornton',
#   'Market': 'US',
#   'Zip.code': 75252.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-132570',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-EN-10003055',
#   'Product.Name': 'Blue String-Tie & Button Interoffice Envelopes, 10 x 13',
#   'SalePrice': 22.2,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 10.2},
#  {'Customer.ID': 'MG-176954',
#   'Customer.Name': 'Maureen Gnade',
#   'Market': 'US',
#   'Zip.code': 77354.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2013-142685',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-SU-10000157',
#   'Product.Name': 'Compact Automatic Electric Letter Opener',
#   'SalePrice': 81.08,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 69.08},
#  {'Customer.ID': 'JO-151454',
#   'Customer.Name': "Jack O'Briant",
#   'Market': 'US',
#   'Zip.code': 76180.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-167486',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10003268',
#   'Product.Name': 'Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#   'SalePrice': 18.29,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.29},
#  {'Customer.ID': 'SP-206204',
#   'Customer.Name': 'Stefania Perrino',
#   'Market': 'US',
#   'Zip.code': 78148.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-112844',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-FU-10004845',
#   'Product.Name': 'Deflect-o EconoMat Nonstudded, No Bevel Mat',
#   'SalePrice': 34.7,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 22.7},
#  {'Customer.ID': 'SP-206204',
#   'Customer.Name': 'Stefania Perrino',
#   'Market': 'US',
#   'Zip.code': 77662.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-112844',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10003988',
#   'Product.Name': 'LF Elite 3D Dazzle Designer Hard Case Cover, Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite',
#   'SalePrice': 20.28,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 8.28},
#  {'Customer.ID': 'MH-180254',
#   'Customer.Name': 'Michelle Huthwaite',
#   'Market': 'US',
#   'Zip.code': 75219.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-150301',
#   'Order.Priority': 'High',
#   'Product.ID': 'FUR-CH-10002647',
#   'Product.Name': 'Situations Contoured Folding Chairs, 4/Set',
#   'SalePrice': 25.38,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 13.38},
#  {'Customer.ID': 'EB-137504',
#   'Customer.Name': 'Edward Becker',
#   'Market': 'US',
#   'Zip.code': 78613.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-166947',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-CH-10004997',
#   'Product.Name': 'Hon Every-Day Series Multi-Task Chairs',
#   'SalePrice': 75.85,
#   'Quantity': 9,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 63.85},
#  {'Customer.ID': 'GT-147104',
#   'Customer.Name': 'Greg Tran',
#   'Market': 'US',
#   'Zip.code': 77489.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-128209',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-BO-10002213',
#   'Product.Name': 'DMI Eclipse Executive Suite Bookcases',
#   'SalePrice': 99.33,
#   'Quantity': 10,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 87.33},
#  {'Customer.ID': 'GT-147104',
#   'Customer.Name': 'Greg Tran',
#   'Market': 'US',
#   'Zip.code': 76051.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-128209',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-BI-10001359',
#   'Product.Name': 'GBC DocuBind TL300 Electric Binding System',
#   'SalePrice': 143.42,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 131.42},
#  {'Customer.ID': 'SS-204104',
#   'Customer.Name': 'Shahid Shariari',
#   'Market': 'US',
#   'Zip.code': 78004.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-145800',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-TA-10001539',
#   'Product.Name': 'Chromcraft Rectangular Conference Tables',
#   'SalePrice': 46.69,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 34.69},
#  {'Customer.ID': 'BM-117854',
#   'Customer.Name': 'Bryan Mills',
#   'Market': 'US',
#   'Zip.code': 76148.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-106971',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10000844',
#   'Product.Name': 'Logitechย\xa0Gaming G510s - Keyboard',
#   'SalePrice': 58.08,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 46.08},
#  {'Customer.ID': 'GZ-144704',
#   'Customer.Name': 'Gary Zandusky',
#   'Market': 'US',
#   'Zip.code': 77005.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-154795',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10002088',
#   'Product.Name': 'Nu-Dell Float Frame 11 x 14 1/2',
#   'SalePrice': 12.83,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.83},
#  {'Customer.ID': 'GZ-144704',
#   'Customer.Name': 'Gary Zandusky',
#   'Market': 'US',
#   'Zip.code': 77864.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-154795',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-EN-10003068',
#   'Product.Name': '#6 3/4 Gummed Flap White Envelopes',
#   'SalePrice': 12.49,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.49},
#  {'Customer.ID': 'SC-200504',
#   'Customer.Name': 'Sample Company A',
#   'Market': 'US',
#   'Zip.code': 77084.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-131275',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10000078',
#   'Product.Name': 'Tennsco 6- and 18-Compartment Lockers',
#   'SalePrice': 105.9,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 93.9},
#  {'Customer.ID': 'SC-200504',
#   'Customer.Name': 'Sample Company A',
#   'Market': 'US',
#   'Zip.code': 75023.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-131275',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'FUR-FU-10004597',
#   'Product.Name': 'Eldon Cleatmat Chair Mats for Medium Pile Carpets',
#   'SalePrice': 15.6,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.6},
#  {'Customer.ID': 'SC-200504',
#   'Customer.Name': 'Sample Company A',
#   'Market': 'US',
#   'Zip.code': 77571.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2011-131275',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-MA-10001148',
#   'Product.Name': 'Swingline SM12-08 MicroCut Jam Free Shredder',
#   'SalePrice': 101.41,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 89.41},
#  {'Customer.ID': 'CB-125354',
#   'Customer.Name': 'Claudia Bergmann',
#   'Market': 'US',
#   'Zip.code': 78228.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2013-165505',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-AR-10003477',
#   'Product.Name': '4009 Highlighters',
#   'SalePrice': 12.34,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.34},
#  {'Customer.ID': 'CB-125354',
#   'Customer.Name': 'Claudia Bergmann',
#   'Market': 'US',
#   'Zip.code': 78723.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2013-165505',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'OFF-ST-10001526',
#   'Product.Name': 'Iceberg Mobile Mega Data/Printer Cart',
#   'SalePrice': 109.0,
#   'Quantity': 13,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 97.0},
#  {'Customer.ID': 'RM-193754',
#   'Customer.Name': 'Raymond Messe',
#   'Market': 'US',
#   'Zip.code': 78377.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-127292',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-AP-10000828',
#   'Product.Name': 'Avanti 4.4 Cu. Ft. Refrigerator',
#   'SalePrice': 81.07,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 69.07},
#  {'Customer.ID': 'RM-193754',
#   'Customer.Name': 'Raymond Messe',
#   'Market': 'US',
#   'Zip.code': 75961.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-127292',
#   'Order.Priority': 'High',
#   'Product.ID': 'OFF-EN-10001509',
#   'Product.Name': 'Poly String Tie Envelopes',
#   'SalePrice': 12.29,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.29},
#  {'Customer.ID': 'RM-193754',
#   'Customer.Name': 'Raymond Messe',
#   'Market': 'US',
#   'Zip.code': 77477.0,
#   'Order.Date': '00:00.0',
# ...
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.8},
#  {'Customer.ID': 'SG-206054',
#   'Customer.Name': 'Speros Goranitis',
#   'Market': 'US',
#   'Zip.code': 77057.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2011-169446',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002817',
#   'Product.Name': 'RCA ViSYS 25425RE1 Corded phone',
#   'SalePrice': 33.47,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 21.47},
#  {'Customer.ID': 'FC-143354',
#   'Customer.Name': 'Fred Chung',
#   'Market': 'US',
#   'Zip.code': 75104.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-121405',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002890',
#   'Product.Name': 'AT&T 17929 Lendline Telephone',
#   'SalePrice': 17.9,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.9},
#  {'Customer.ID': 'BF-111704',
#   'Customer.Name': 'Ben Ferrer',
#   'Market': 'US',
#   'Zip.code': 78259.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-145835',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004447',
#   'Product.Name': 'Toshiba IPT2010-SD IPย\xa0Telephone',
#   'SalePrice': 25.5,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 13.5},
#  {'Customer.ID': 'MG-176954',
#   'Customer.Name': 'Maureen Gnade',
#   'Market': 'US',
#   'Zip.code': 75115.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-164007',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10003433',
#   'Product.Name': 'Maxell 4.7GB DVD+R 5/Pack',
#   'SalePrice': 12.18,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.18},
#  {'Customer.ID': 'RL-196154',
#   'Customer.Name': 'Rob Lucas',
#   'Market': 'US',
#   'Zip.code': 75103.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-126557',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10003963',
#   'Product.Name': 'GE 2-Jack Phone Line Splitter',
#   'SalePrice': 49.56,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 37.56},
#  {'Customer.ID': 'RL-196154',
#   'Customer.Name': 'Rob Lucas',
#   'Market': 'US',
#   'Zip.code': 77041.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-126557',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10003505',
#   'Product.Name': 'Geemarc AmpliPOWER60',
#   'SalePrice': 24.0,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 12.0},
#  {'Customer.ID': 'RL-196154',
#   'Customer.Name': 'Rob Lucas',
#   'Market': 'US',
#   'Zip.code': 76834.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-126557',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10000526',
#   'Product.Name': 'Vtech CS6719',
#   'SalePrice': 136.92,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 124.92},
#  {'Customer.ID': 'TS-213704',
#   'Customer.Name': 'Todd Sumrall',
#   'Market': 'US',
#   'Zip.code': 77095.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-100377',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-CO-10001046',
#   'Product.Name': 'Canon Imageclass D680 Copier / Fax',
#   'SalePrice': 298.3,
#   'Quantity': 5,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 286.3},
#  {'Customer.ID': 'MC-176054',
#   'Customer.Name': 'Matt Connell',
#   'Market': 'US',
#   'Zip.code': 79605.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-145394',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001051',
#   'Product.Name': 'HTC One',
#   'SalePrice': 27.01,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 15.01},
#  {'Customer.ID': 'DR-128804',
#   'Customer.Name': 'Dan Reichenbach',
#   'Market': 'US',
#   'Zip.code': 76109.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-159982',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001580',
#   'Product.Name': 'Logitech Mobile Speakerphone P710e -ย\xa0speaker phone',
#   'SalePrice': 63.81,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 51.81},
#  {'Customer.ID': 'EK-137954',
#   'Customer.Name': 'Eileen Kiefer',
#   'Market': 'US',
#   'Zip.code': 77505.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2012-109113',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-AC-10004761',
#   'Product.Name': 'Maxell 4.7GB DVD+RW 3/Pack',
#   'SalePrice': 16.68,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 4.68},
#  {'Customer.ID': 'KD-163454',
#   'Customer.Name': 'Katherine Ducich',
#   'Market': 'US',
#   'Zip.code': 76201.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-123218',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10000736',
#   'Product.Name': 'Logitech G600 MMO Gaming Mouse',
#   'SalePrice': 27.25,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 15.25},
#  {'Customer.ID': 'KD-163454',
#   'Customer.Name': 'Katherine Ducich',
#   'Market': 'US',
#   'Zip.code': 77031.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2012-123218',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001061',
#   'Product.Name': 'Apple iPhone 5C',
#   'SalePrice': 26.36,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 14.36},
#  {'Customer.ID': 'ME-173204',
#   'Customer.Name': 'Maria Etezadi',
#   'Market': 'US',
#   'Zip.code': 77536.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-152555',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001254',
#   'Product.Name': 'Jabra BIZ 2300 Duo QD Duo Cordedย\xa0Headset',
#   'SalePrice': 68.85,
#   'Quantity': 8,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 56.85},
#  {'Customer.ID': 'AF-108704',
#   'Customer.Name': 'Art Ferguson',
#   'Market': 'US',
#   'Zip.code': 77845.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-139234',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-AC-10004510',
#   'Product.Name': 'Logitech Desktop MK120 Mouse and keyboard Combo',
#   'SalePrice': 15.9,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.9},
#  {'Customer.ID': 'KL-166454',
#   'Customer.Name': 'Ken Lonsdale',
#   'Market': 'US',
#   'Zip.code': 77868.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-133725',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004165',
#   'Product.Name': 'Mitel MiVoice 5330e IP Phone',
#   'SalePrice': 154.89,
#   'Quantity': 9,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 142.89},
#  {'Customer.ID': 'KL-166454',
#   'Customer.Name': 'Ken Lonsdale',
#   'Market': 'US',
#   'Zip.code': 75214.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-157749',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10000011',
#   'Product.Name': 'PureGear Roll-On Screen Protector',
#   'SalePrice': 14.01,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.01},
#  {'Customer.ID': 'RC-198254',
#   'Customer.Name': 'Roy Collins',
#   'Market': 'US',
#   'Zip.code': 75010.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-125318',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001433',
#   'Product.Name': 'Cisco Small Business SPA 502G VoIP phone',
#   'SalePrice': 41.26,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 29.26},
#  {'Customer.ID': 'RF-197354',
#   'Customer.Name': 'Roland Fjeld',
#   'Market': 'US',
#   'Zip.code': 75048.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-110044',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10001299',
#   'Product.Name': 'Polycom CX300 Desktop Phone USB VoIP phone',
#   'SalePrice': 66.73,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 54.73},
#  {'Customer.ID': 'RB-194654',
#   'Customer.Name': 'Rick Bensley',
#   'Market': 'US',
#   'Zip.code': 77584.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-158568',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10001767',
#   'Product.Name': 'SanDisk Ultra 64 GB MicroSDHC Class 10 Memory Card',
#   'SalePrice': 22.01,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 10.01},
#  {'Customer.ID': 'XP-218654',
#   'Customer.Name': 'Xylona Preis',
#   'Market': 'US',
#   'Zip.code': 77379.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-129196',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10002473',
#   'Product.Name': 'Maxell 4.7GB DVD-R',
#   'SalePrice': 15.81,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.81},
#  {'Customer.ID': 'BB-115454',
#   'Customer.Name': 'Brenda Bowman',
#   'Market': 'US',
#   'Zip.code': 75569.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-124506',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10003280',
#   'Product.Name': 'Belkin F8E887 USB Wired Ergonomic Keyboard',
#   'SalePrice': 18.45,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.45},
#  {'Customer.ID': 'RD-197204',
#   'Customer.Name': 'Roger Demir',
#   'Market': 'US',
#   'Zip.code': 77069.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-146157',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10003657',
#   'Product.Name': 'Lenovo 17-Key USB Numeric Keypad',
#   'SalePrice': 23.91,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 11.91},
#  {'Customer.ID': 'GG-146504',
#   'Customer.Name': 'Greg Guthrie',
#   'Market': 'US',
#   'Zip.code': 76240.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2013-129686',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-AC-10001266',
#   'Product.Name': 'Memorex Micro Travel Drive 8 GB',
#   'SalePrice': 27.23,
#   'Quantity': 6,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 15.23},
#  {'Customer.ID': 'RW-196304',
#   'Customer.Name': 'Rob Williams',
#   'Market': 'US',
#   'Zip.code': 79424.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2013-131114',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10000199',
#   'Product.Name': 'Kingston Digital DataTraveler 8GB USB 2.0',
#   'SalePrice': 13.71,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.71},
#  {'Customer.ID': 'JK-161204',
#   'Customer.Name': 'Julie Kriz',
#   'Market': 'US',
#   'Zip.code': 78251.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-154039',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002789',
#   'Product.Name': 'LG Exalt',
#   'SalePrice': 18.3,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 6.3},
#  {'Customer.ID': 'SU-206654',
#   'Customer.Name': 'Stephanie Ulpright',
#   'Market': 'US',
#   'Zip.code': 76134.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-157966',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-CO-10001449',
#   'Product.Name': 'Hewlett Packard LaserJet 3310 Copier',
#   'SalePrice': 239.5,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 227.5},
#  {'Customer.ID': 'SU-206654',
#   'Customer.Name': 'Stephanie Ulpright',
#   'Market': 'US',
#   'Zip.code': 75219.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-157966',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-PH-10001527',
#   'Product.Name': 'Plantronics MX500i Earset',
#   'SalePrice': 23.32,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 11.32},
#  {'Customer.ID': 'BN-114704',
#   'Customer.Name': 'Brad Norvell',
#   'Market': 'US',
#   'Zip.code': 79756.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-114370',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10000213',
#   'Product.Name': 'Seidio BD2-HK3IPH5-BK DILEX Case and Holster Combo for Apple iPhone 5/5s - Black',
#   'SalePrice': 17.21,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 5.21},
#  {'Customer.ID': 'JF-154904',
#   'Customer.Name': 'Jeremy Farry',
#   'Market': 'US',
#   'Zip.code': 78244.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-162124',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10001990',
#   'Product.Name': 'Kensington Orbit Wireless Mobile Trackball for PC and Mac',
#   'SalePrice': 21.29,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 9.29},
#  {'Customer.ID': 'ML-177554',
#   'Customer.Name': 'Max Ludwig',
#   'Market': 'US',
#   'Zip.code': 79605.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-140242',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10004659',
#   'Product.Name': 'Imationย\xa0Secure+ Hardware Encrypted USB 2.0ย\xa0Flash Drive; 16GB',
#   'SalePrice': 41.74,
#   'Quantity': 7,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 29.74},
#  {'Customer.ID': 'JD-160154',
#   'Customer.Name': 'Joy Daniels',
#   'Market': 'US',
#   'Zip.code': 76126.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-152569',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10002185',
#   'Product.Name': 'QVS USB Car Charger 2-Port 2.1Amp for iPod/iPhone/iPad/iPad 2/iPad 3',
#   'SalePrice': 12.7,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 0.7},
#  {'Customer.ID': 'SD-204854',
#   'Customer.Name': 'Shirley Daniels',
#   'Market': 'US',
#   'Zip.code': nan,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-102337',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10002564',
#   'Product.Name': 'OtterBox Defender Series Case - Samsung Galaxy S4',
#   'SalePrice': 22.47,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 10.47},
#  {'Customer.ID': 'GH-144104',
#   'Customer.Name': 'Gary Hansen',
#   'Market': 'US',
#   'Zip.code': 76712.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-163006',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-PH-10002584',
#   'Product.Name': 'Samsung Galaxy S4',
#   'SalePrice': 91.67,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 79.67},
#  {'Customer.ID': 'KW-164354',
#   'Customer.Name': 'Katrina Willman',
#   'Market': 'US',
#   'Zip.code': nan,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-115805',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-PH-10003092',
#   'Product.Name': 'Motorola L804',
#   'SalePrice': 22.83,
#   'Quantity': 1,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 10.83},
#  {'Customer.ID': 'AT-107354',
#   'Customer.Name': 'Annie Thurman',
#   'Market': 'US',
#   'Zip.code': 75092.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-135034',
#   'Order.Priority': 'Critical',
#   'Product.ID': 'TEC-PH-10003931',
#   'Product.Name': 'JBL Micro Wireless Portable Bluetooth Speaker',
#   'SalePrice': 21.23,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 9.23},
#  {'Customer.ID': 'MC-181004',
#   'Customer.Name': 'Mick Crebagga',
#   'Market': 'US',
#   'Zip.code': 77479.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-113075',
#   'Order.Priority': 'High',
#   'Product.ID': 'TEC-AC-10003441',
#   'Product.Name': 'Kingston Digital DataTraveler 32GB USB 2.0',
#   'SalePrice': 19.53,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 7.53},
#  {'Customer.ID': 'MY-182954',
#   'Customer.Name': 'Muhammed Yedwab',
#   'Market': 'US',
#   'Zip.code': 75048.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-167626',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-AC-10004353',
#   'Product.Name': 'Hypercom P1300 Pinpad',
#   'SalePrice': 15.68,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 3.68},
#  {'Customer.ID': 'DB-130604',
#   'Customer.Name': 'Dave Brooks',
#   'Market': 'US',
#   'Zip.code': 77584.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-132353',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004536',
#   'Product.Name': 'Avaya 5420 Digital phone',
#   'SalePrice': 66.02,
#   'Quantity': 3,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 54.02},
#  {'Customer.ID': 'LC-168704',
#   'Customer.Name': 'Lena Cacioppo',
#   'Market': 'US',
#   'Zip.code': 79830.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'US-2014-125647',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004188',
#   'Product.Name': 'OtterBox Commuter Series Case - Samsung Galaxy S4',
#   'SalePrice': 14.88,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 2.88},
#  {'Customer.ID': 'MA-175604',
#   'Customer.Name': 'Matt Abelman',
#   'Market': 'US',
#   'Zip.code': 76706.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-110373',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10001536',
#   'Product.Name': 'Spigen Samsung Galaxy S5 Case Wallet',
#   'SalePrice': 13.33,
#   'Quantity': 2,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 1.33},
#  {'Customer.ID': 'CY-127454',
#   'Customer.Name': 'Craig Yedwab',
#   'Market': 'US',
#   'Zip.code': 75082.0,
#   'Order.Date': '00:00.0',
#   'Order.ID': 'CA-2014-117114',
#   'Order.Priority': 'Medium',
#   'Product.ID': 'TEC-PH-10004042',
#   'Product.Name': 'ClearOne Communications CHAT 70 OCย\xa0Speaker Phone',
#   'SalePrice': 47.39,
#   'Quantity': 4,
#   'Ship.Date': '00:00.0',
#   'Shipping.Cost': 35.39}]

# %% [markdown]
# # 🧩 3. สร้างฐานข้อมูลใหม่

# %%
db = client["BIDB"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-hrsi8p3-shard-00-01.3uz0c0m.mongodb.net:27017', 'ac-hrsi8p3-shard-00-00.3uz0c0m.mongodb.net:27017', 'ac-hrsi8p3-shard-00-02.3uz0c0m.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-37mxtc-shard-0', tls=True), 'BIdata')

# %% [markdown]
# # 🧩 4. Insert ข้อมูล

# %%
# .insert

db.BIdata.insert_many(dic_bi)
# Out:
# InsertManyResult([ObjectId('667071d7300a454c5653ce71'), ObjectId('667071d7300a454c5653ce72'), ObjectId('667071d7300a454c5653ce73'), ObjectId('667071d7300a454c5653ce74'), ObjectId('667071d7300a454c5653ce75'), ObjectId('667071d7300a454c5653ce76'), ObjectId('667071d7300a454c5653ce77'), ObjectId('667071d7300a454c5653ce78'), ObjectId('667071d7300a454c5653ce79'), ObjectId('667071d7300a454c5653ce7a'), ObjectId('667071d7300a454c5653ce7b'), ObjectId('667071d7300a454c5653ce7c'), ObjectId('667071d7300a454c5653ce7d'), ObjectId('667071d7300a454c5653ce7e'), ObjectId('667071d7300a454c5653ce7f'), ObjectId('667071d7300a454c5653ce80'), ObjectId('667071d7300a454c5653ce81'), ObjectId('667071d7300a454c5653ce82'), ObjectId('667071d7300a454c5653ce83'), ObjectId('667071d7300a454c5653ce84'), ObjectId('667071d7300a454c5653ce85'), ObjectId('667071d7300a454c5653ce86'), ObjectId('667071d7300a454c5653ce87'), ObjectId('667071d7300a454c5653ce88'), ObjectId('667071d7300a454c5653ce89'), ObjectId('667071d7300a454c5653ce8a'), ObjectId('667071d7300a454c5653ce8b'), ObjectId('667071d7300a454c5653ce8c'), ObjectId('667071d7300a454c5653ce8d'), ObjectId('667071d7300a454c5653ce8e'), ObjectId('667071d7300a454c5653ce8f'), ObjectId('667071d7300a454c5653ce90'), ObjectId('667071d7300a454c5653ce91'), ObjectId('667071d7300a454c5653ce92'), ObjectId('667071d7300a454c5653ce93'), ObjectId('667071d7300a454c5653ce94'), ObjectId('667071d7300a454c5653ce95'), ObjectId('667071d7300a454c5653ce96'), ObjectId('667071d7300a454c5653ce97'), ObjectId('667071d7300a454c5653ce98'), ObjectId('667071d7300a454c5653ce99'), ObjectId('667071d7300a454c5653ce9a'), ObjectId('667071d7300a454c5653ce9b'), ObjectId('667071d7300a454c5653ce9c'), ObjectId('667071d7300a454c5653ce9d'), ObjectId('667071d7300a454c5653ce9e'), ObjectId('667071d7300a454c5653ce9f'), ObjectId('667071d7300a454c5653cea0'), ObjectId('667071d7300a454c5653cea1'), ObjectId('667071d7300a454c5653cea2'), ObjectId('667071d7300a454c5653cea3'), ObjectId('667071d7300a454c5653cea4'), ObjectId('667071d7300a454c5653cea5'), ObjectId('667071d7300a454c5653cea6'), ObjectId('667071d7300a454c5653cea7'), ObjectId('667071d7300a454c5653cea8'), ObjectId('667071d7300a454c5653cea9'), ObjectId('667071d7300a454c5653ceaa'), ObjectId('667071d7300a454c5653ceab'), ObjectId('667071d7300a454c5653ceac'), ObjectId('667071d7300a454c5653cead'), ObjectId('667071d7300a454c5653ceae'), ObjectId('667071d7300a454c5653ceaf'), ObjectId('667071d7300a454c5653ceb0'), ObjectId('667071d7300a454c5653ceb1'), ObjectId('667071d7300a454c5653ceb2'), ObjectId('667071d7300a454c5653ceb3'), ObjectId('667071d7300a454c5653ceb4'), ObjectId('667071d7300a454c5653ceb5'), ObjectId('667071d7300a454c5653ceb6'), ObjectId('667071d7300a454c5653ceb7'), ObjectId('667071d7300a454c5653ceb8'), ObjectId('667071d7300a454c5653ceb9'), ObjectId('667071d7300a454c5653ceba'), ObjectId('667071d7300a454c5653cebb'), ObjectId('667071d7300a454c5653cebc'), ObjectId('667071d7300a454c5653cebd'), ObjectId('667071d7300a454c5653cebe'), ObjectId('667071d7300a454c5653cebf'), ObjectId('667071d7300a454c5653cec0'), ObjectId('667071d7300a454c5653cec1'), ObjectId('667071d7300a454c5653cec2'), ObjectId('667071d7300a454c5653cec3'), ObjectId('667071d7300a454c5653cec4'), ObjectId('667071d7300a454c5653cec5'), ObjectId('667071d7300a454c5653cec6'), ObjectId('667071d7300a454c5653cec7'), ObjectId('667071d7300a454c5653cec8'), ObjectId('667071d7300a454c5653cec9'), ObjectId('667071d7300a454c5653ceca'), ObjectId('667071d7300a454c5653cecb'), ObjectId('667071d7300a454c5653cecc'), ObjectId('667071d7300a454c5653cecd'), ObjectId('667071d7300a454c5653cece'), ObjectId('667071d7300a454c5653cecf'), ObjectId('667071d7300a454c5653ced0'), ObjectId('667071d7300a454c5653ced1'), ObjectId('667071d7300a454c5653ced2'), ObjectId('667071d7300a454c5653ced3'), ObjectId('667071d7300a454c5653ced4'), ObjectId('667071d7300a454c5653ced5'), ObjectId('667071d7300a454c5653ced6'), ObjectId('667071d7300a454c5653ced7'), ObjectId('667071d7300a454c5653ced8'), ObjectId('667071d7300a454c5653 ...

# %%
# แสดงรายการฐานข้อมูล

client.list_database_names()
# Out:
# ['BIDB', 'Country', 'sample_mflix', 'admin', 'local']

# %%
import requests

# %% [markdown]
# # END
